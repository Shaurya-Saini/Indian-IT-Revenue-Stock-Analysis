# %% [markdown]
# # TATA CONSULTANCY SERVICES (TCS)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Largecap_rev.xlsx")
df
# Out:
#     COMPANY TIME PERIOD  REVENUE (in Cr)  REVENUE GROWTH RATE
# 0   INFOSYS  2024-04-01           153670             4.700000
# 1   INFOSYS  2023-04-01           146767            20.600000
# 2   INFOSYS  2022-04-01           121641            21.000000
# 3   INFOSYS  2021-04-01           100472            10.600000
# 4   INFOSYS  2020-04-01            90791             9.816752
# 5   INFOSYS  2019-04-01            82675            17.232920
# 6   INFOSYS  2018-04-01            70522             2.975878
# 7   INFOSYS  2017-04-01            68484             9.677936
# 8   INFOSYS  2016-04-01            62441            17.108348
# 9   INFOSYS  2015-04-01            53319             6.355095
# 10  INFOSYS  2014-04-01            50133            20.600000
# 11      TCS  2024-04-01           240893             6.800000
# 12      TCS  2023-04-01           225458            17.576687
# 13      TCS  2022-04-01           191754            16.797115
# 14      TCS  2021-04-01           164177             4.605318
# 15      TCS  2020-04-01           156949             7.159487
# 16      TCS  2019-04-01           146463            18.975013
# 17      TCS  2018-04-01           123104             4.355492
# 18      TCS  2017-04-01           117966             8.578319
# 19      TCS  2016-04-01           108646            14.789536
# 20      TCS  2015-04-01            94648            15.693872
# 21      TCS  2014-04-01            81809            29.877243
# 22    WIPRO  2024-04-01            89794            -1.253656
# 23    WIPRO  2023-04-01            90934            14.342118
# 24    WIPRO  2022-04-01            79528            27.772244
# 25    WIPRO  2021-04-01            62242             1.470492
# 26    WIPRO  2020-04-01            61340             4.132007
# 27    WIPRO  2019-04-01            58906             7.817333
# 28    WIPRO  2018-04-01            54635            -1.411119
# 29    WIPRO  2017-04-01            55417             7.334883
# 30    WIPRO  2016-04-01            51630             9.112811
# 31    WIPRO  2015-04-01            47318             8.125771
# 32    WIPRO  2014-04-01            43762            16.116536

# %%
result = pd.read_csv("large_cap_stock.csv")
result
# Out:
#           Date      INFY.NS       TCS.NS    WIPRO.NS  TCS_Return  INFY_Return  \
# 0   2014-04-01   426.816986  1054.946655  105.917091   38.063461    21.595681
# 1   2015-04-01   480.294159  1057.828979   98.330406   12.529298     0.273220
# 2   2016-04-01   412.069702  1039.676514   90.426605  -14.204723    -1.716011
# 3   2017-04-01   469.689941  1241.495850   99.243690   13.983129    19.411743
# 4   2018-04-01   632.609375  1768.772583  120.578621   34.686592    42.471083
# 5   2019-04-01   570.777344  1680.097778   93.478180   -9.774125    -5.013353
# 6   2020-04-01  1247.051758  2957.091064  197.704391  118.483051    76.007081
# 7   2021-04-01  1772.524414  3517.693604  283.479218   42.137197    18.957906
# 8   2022-04-01  1356.077148  3113.397705  178.304642  -23.494586   -11.493210
# 9   2023-04-01  1460.432129  3820.962891  235.372940    7.695357    22.726463
# 10  2024-04-01  1856.400024  3934.850098  308.100006   27.113064     2.980589
#
#     WIPRO_Return
# 0      18.854497
# 1      -7.162853
# 2      -8.038003
# 3       9.750543
# 4      21.497518
# 5     -22.475328
# 6     111.497904
# 7      43.385392
# 8     -37.101336
# 9      32.006064
# 10     30.898652

# %%
lis = ["TCS.NS","TCS_Return"]
tcs_st = result[lis]
tcs_st = tcs_st.copy()
tcs_st["INDEX"]=np.arange(0,11)
tcs_st
# Out:
#          TCS.NS  TCS_Return  INDEX
# 0   1054.946655   38.063461      0
# 1   1057.828979   12.529298      1
# 2   1039.676514  -14.204723      2
# 3   1241.495850   13.983129      3
# 4   1768.772583   34.686592      4
# 5   1680.097778   -9.774125      5
# 6   2957.091064  118.483051      6
# 7   3517.693604   42.137197      7
# 8   3113.397705  -23.494586      8
# 9   3820.962891    7.695357      9
# 10  3934.850098   27.113064     10

# %%
tcs_re = df[df["COMPANY"]=="TCS"]
tcs_re = tcs_re.copy()
tcs_re["INDEX"]=np.flip(np.arange(0,11))
tcs_re
# Out:
#    COMPANY TIME PERIOD  REVENUE (in Cr)  REVENUE GROWTH RATE  INDEX
# 11     TCS  2024-04-01           240893             6.800000     10
# 12     TCS  2023-04-01           225458            17.576687      9
# 13     TCS  2022-04-01           191754            16.797115      8
# 14     TCS  2021-04-01           164177             4.605318      7
# 15     TCS  2020-04-01           156949             7.159487      6
# 16     TCS  2019-04-01           146463            18.975013      5
# 17     TCS  2018-04-01           123104             4.355492      4
# 18     TCS  2017-04-01           117966             8.578319      3
# 19     TCS  2016-04-01           108646            14.789536      2
# 20     TCS  2015-04-01            94648            15.693872      1
# 21     TCS  2014-04-01            81809            29.877243      0

# %%
tcs = pd.merge(tcs_re,tcs_st)
tcs = tcs.sort_values("INDEX")
tcs = tcs.drop("INDEX",axis=1)
tcs = tcs.drop("COMPANY",axis=1)
tcs
# Out:
#    TIME PERIOD  REVENUE (in Cr)  REVENUE GROWTH RATE       TCS.NS  TCS_Return
# 10  2014-04-01            81809            29.877243  1054.946655   38.063461
# 9   2015-04-01            94648            15.693872  1057.828979   12.529298
# 8   2016-04-01           108646            14.789536  1039.676514  -14.204723
# 7   2017-04-01           117966             8.578319  1241.495850   13.983129
# 6   2018-04-01           123104             4.355492  1768.772583   34.686592
# 5   2019-04-01           146463            18.975013  1680.097778   -9.774125
# 4   2020-04-01           156949             7.159487  2957.091064  118.483051
# 3   2021-04-01           164177             4.605318  3517.693604   42.137197
# 2   2022-04-01           191754            16.797115  3113.397705  -23.494586
# 1   2023-04-01           225458            17.576687  3820.962891    7.695357
# 0   2024-04-01           240893             6.800000  3934.850098   27.113064

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

sns.lineplot(data=tcs, x="TIME PERIOD", y="REVENUE (in Cr)", ax=ax1, color="blue")
ax1.set_ylabel("Revenue (in Cr)", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")
ax1.set_ylim(0, tcs["REVENUE (in Cr)"].max() * 1.1)

ax2 = ax1.twinx()
sns.lineplot(data=tcs, x="TIME PERIOD", y="TCS.NS", ax=ax2, color="red",linestyle="dashed")
ax2.set_ylabel("Stock price", color="red")
ax2.tick_params(axis="y", labelcolor="red")
ax2.set_ylim(0, tcs["TCS.NS"].max() * 1.1)

legend_labels = [
    plt.Line2D([0], [0], color="blue", lw=2, label="Revenue"),
    plt.Line2D([0], [0], color="red", lw=2, linestyle="dashed", label="Stock Price")
]
ax1.legend(handles=legend_labels, loc="upper left")

ax1.set_xlabel("Date")
plt.title("TCS: Revenue vs. Stock Price")
# Out:
# Text(0.5, 1.0, 'TCS: Revenue vs. Stock Price')

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

sns.lineplot(data=tcs, x="TIME PERIOD", y="REVENUE GROWTH RATE", ax=ax1, color="blue")
ax1.set_ylabel("Revenue growth rate", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")

ax2 = ax1.twinx()
sns.lineplot(data=tcs, x="TIME PERIOD", y="TCS_Return", ax=ax2, color="red",linestyle="dashed")
ax2.set_ylabel("Stock return", color="red")
ax2.tick_params(axis="y", labelcolor="red")

min_y = min(tcs["REVENUE GROWTH RATE"].min(), tcs["TCS_Return"].min()) * 1.1
max_y = max(tcs["REVENUE GROWTH RATE"].max(), tcs["TCS_Return"].max()) * 1.1
ax1.set_ylim(min_y, max_y)
ax2.set_ylim(min_y, max_y)

legend_labels = [
    plt.Line2D([0], [0], color="blue", lw=2, label="Revenue growth rate"),
    plt.Line2D([0], [0], color="red", lw=2, linestyle="dashed", label="Stock Return")
]
ax1.legend(handles=legend_labels, loc="upper left")

ax1.set_xlabel("Date")
plt.title("TCS: Revenue growth rate vs. Stock Return")
# Out:
# Text(0.5, 1.0, 'TCS: Revenue growth rate vs. Stock Return')
